# %%
import os
import sys
import pandas as pd
import numpy as np  

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from Portafolio.Submitfull import Submitfull

# %%
filtro_colums = pd.read_excel("../Datos/SubFiltro.xlsx",sheet_name=0)

# %%
filtro_colums.head()
# Out:
#                                 var1                      var2      corr  Lags
# 0  returns_53_MEX_GRUPO MEXICO_MATER       65_PER_COPPER_MATER  0.450230     7
# 1          returns_19_CHL_ITAU_FINAN        41_COL_ARGOS_MATER  0.322044    11
# 2      returns_33_COL_ECOPETROL_ENER       65_PER_COPPER_MATER  0.320043     3
# 3      returns_33_COL_ECOPETROL_ENER    60_PER_CREDICORP_FINAN  0.317299     3
# 4          returns_19_CHL_ITAU_FINAN  32_COL_BANCOLOMBIA_FINAN  0.316430     5

# %%
model = list(filtro_colums["var1"])
model.extend(list(filtro_colums["var2"]))
model = list(set(model))
model.append("PERIODO")
model.reverse()
model
# Out:
# ['PERIODO',
#  '52_MEX_BANORTE_FINAN',
#  '1_CHL_AGUAS_SERV. P',
#  '16_CHL_QUINENCO_FINAN',
#  '41_COL_ARGOS_MATER',
#  '19_CHL_ITAU_FINAN',
#  '2_CHL_ANDINA_CONS. BAS',
#  '69_PER_VOLCAN_MATER',
#  '12_CHL_COPEC_ENER',
#  '14_CHL_FALABELLA_CONS. DISCRE',
#  '75_PER_TREVALI MINING_MATER',
#  '58_MEX_PTO LIVERPOOL_CONS. DISCRE',
#  '18_CHL_VAPORES_INDUST',
#  '7_CHL_CIA CERVECERIAS_CONS. BAS',
#  '28_CHL_ENGIE ENERGIA_SERV. P',
#  '32_COL_BANCOLOMBIA_FINAN',
#  '50_MEX_GRUPO CARSO_CONS. DISCRE',
#  '26_CHL_ORO BLANCO_FINAN',
#  '38_COL_DAVIVIENDA_FINAN',
#  '10_CHL_CMPC_MATER',
#  '49_MEX_AEREO PACIFICO_INDUST',
#  '35_COL_SURAMERICANA_FINAN',
#  '5_CHL_BANCO STDER_FINAN',
#  '45_MEX_BANCO STDER_FINAN',
#  '60_PER_CREDICORP_FINAN',
#  '8_CHL_CENCOSUD_CONS. BAS',
#  '34_COL_ENER. BOGOTA_SERV. P',
#  '9_CHL_BANCO_CHILE_FINAN',
#  '46_MEX_CEMEX_MATER',
#  '6_CHL_CAP_MATER',
#  '66_PER_MINAS BUENAV._MATER',
#  '71_PER_FERREYROS_INDUST',
#  '53_MEX_GRUPO MEXICO_MATER',
# ...

# %%
df = pd.read_excel("../Datos/Acciones.xlsx",sheet_name=0)
df = df.loc[:,model]

# %%
# df_prepandemia = df[df["PERIODO"]<="2020-03-01"]
# df_pandemia = df[df["PERIODO"]>"2020-03-01"]

# %%
full_analysis = Submitfull(df,data_type="full", lag_model=True)
full_analysis.submit()
full_analysis.escritura_info()
full_analysis.escritura_info(type="resultados")
# Out:
# Nas: returns_52_MEX_BANORTE_FINAN                 1
# returns_1_CHL_AGUAS_SERV. P                  1
# returns_16_CHL_QUINENCO_FINAN                1
# returns_41_COL_ARGOS_MATER                   1
# returns_19_CHL_ITAU_FINAN                    1
# returns_2_CHL_ANDINA_CONS. BAS               1
# returns_69_PER_VOLCAN_MATER                  1
# returns_12_CHL_COPEC_ENER                    1
# returns_14_CHL_FALABELLA_CONS. DISCRE        1
# returns_75_PER_TREVALI MINING_MATER          1
# returns_58_MEX_PTO LIVERPOOL_CONS. DISCRE    1
# returns_18_CHL_VAPORES_INDUST                1
# returns_7_CHL_CIA CERVECERIAS_CONS. BAS      1
# returns_28_CHL_ENGIE ENERGIA_SERV. P         1
# returns_32_COL_BANCOLOMBIA_FINAN             1
# returns_50_MEX_GRUPO CARSO_CONS. DISCRE      1
# returns_26_CHL_ORO BLANCO_FINAN              1
# returns_38_COL_DAVIVIENDA_FINAN              1
# returns_10_CHL_CMPC_MATER                    1
# returns_49_MEX_AEREO PACIFICO_INDUST         1
# ...

# %%
full_analysis.test_results

# %%
# prepandemia_analysis = Submitfull(df_prepandemia, data_type="Prepandemia")
# prepandemia_analysis.submit()
# prepandemia_analysis.escritura_info()
# prepandemia_analysis.escritura_info(type="resultados")

# %%
# pandemia_analysis = Submitfull(df_pandemia, data_type="Pandemia")
# pandemia_analysis.submit()
# pandemia_analysis.escritura_info()
# pandemia_analysis.escritura_info(type="resultados")

# %%
modelos_compartidos = full_analysis.filter_test_results.merge(prepandemia_analysis.filter_test_results, on=["var1", "var2"])
modelos_compartidos = modelos_compartidos.merge(pandemia_analysis.filter_test_results, on=["var1", "var2"])

# %%
modelos_compartidos["Modelos_compartidos"] = "Los tres"
modelos_compartidos.to_csv("Acciones_siempre_recomendadas.csv",index=False)

# %%
toda_pre = full_analysis.filter_test_results.merge(prepandemia_analysis.filter_test_results, on=["var1", "var2"])
toda_pre["Modelos_compartidos"] = "Full y Pre"

# %%
toda_pan = full_analysis.filter_test_results.merge(pandemia_analysis.filter_test_results, on=["var1", "var2"])
toda_pan["Modelos_compartidos"] = "Full y pandemia"

# %%
pre_pan = prepandemia_analysis.filter_test_results.merge(pandemia_analysis.filter_test_results, on=["var1", "var2"])
pre_pan["Modelos_compartidos"] = "Pre y pandemia"
